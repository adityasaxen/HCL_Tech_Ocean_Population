# %% [markdown]
# #  Week 4, Day 7 — June 14, 2026

# %%
from google.colab import drive
drive.mount('/content/drive')
import os, shutil, getpass, datetime, json, glob
BASE_DIR = "/content/drive/MyDrive/Ocean_Plastic_Project"
DIRS = {
    "raw":            BASE_DIR + "/data/raw",
    "processed":      BASE_DIR + "/data/processed",
    "metadata":       BASE_DIR + "/data/metadata",
    "visualizations": BASE_DIR + "/visualizations",
    "notebooks":      BASE_DIR + "/notebooks",
}
print('Drive mounted  | Paths restored ')

# %% [markdown]
# ## Step 1 — Generate WPR 4

# %%
wpr_path = DIRS['metadata'] + '/WPR4_Week4_Jun08_14.txt'
with open(wpr_path, 'w') as f:
    f.write('AMITY UNIVERSITY NOIDA\n')
    f.write('NTCC WEEKLY PROGRESS REPORT — WEEK 4\n')
    f.write('='*70 + '\n')
    f.write('Student Name      : Aditya Saxena\n')
    f.write('Enrollment No.    : A010145025085\n')
    f.write('Faculty Guide     : Dr. Sudhriti Sengupta\n')
    f.write('Organization      : HCLTech\n')
    f.write('Industry Mentor   : Amit Singh\n')
    f.write('Project Title     : Spatio-temporal Analysis of Ocean Plastic Density\n')
    f.write('                    and its Impact on Marine Biodiversity\n')
    f.write(f'Report Period     : June 8 - June 14, 2026\n')
    f.write(f'Date of Submission: {datetime.datetime.now().strftime("%B %d, %Y")}\n')
    f.write('='*70 + '\n\n')
    f.write('1. OBJECTIVES FOR THIS WEEK:\n')
    f.write('   a) Programmatically extract and map High-Density Plastic Zones (hotspots)\n')
    f.write('   b) Conduct source-based breakdown: Urban vs Fishing vs Industrial\n')
    f.write('   c) Calculate Feature Engineering KPIs: Temp Change and Regional Contribution\n')
    f.write('   d) Plot 10-year trajectories overlaying plastic density vs species population\n')
    f.write('   e) Segment trend visualizations by Habitat Type\n')
    f.write('   f) Export all visual canvases and outline ML architecture for Week 5\n\n')

    f.write('2. WORK COMPLETED (DAY BY DAY):\n')
    days = [
        ('June 8 (Mon)', 'Programmatically extracted and mapped High-Density Plastic Zones '
         'using master spatial grid. Applied 80th percentile threshold to identify hotspot cells. '
         '31 hotspot grid cells identified. Generated Seaborn heatmap of plastic density '
         'across Arabian Sea and Bay of Bengal grid. Hotspots concentrated near Gujarat coast '
         '(17N, 70E) and Bay of Bengal delta zone (25N, 88E).'),
        ('June 9 (Tue)', 'Conducted source-based breakdown analysis using Pandas groupby operations. '
         'Calculated whether pollution concentrations in hotspot zones originate from Urban, '
         'Fishing, or Industrial activities. PVC and PS (Industrial) dominate 46 and 33 cells '
         'respectively. PET, PE, PP (Consumer/Urban) present in 91 cells. '
         'Zone contribution pie chart saved.'),
        ('June 10 (Wed)', 'Calculated required Feature Engineering KPIs. '
         'KPI 1: Annual Temperature Change (Current Year minus Previous Year) — '
         'computed using first-difference on GlobalTemperatures annual averages. '
         'KPI 2: Regional Contribution ratios — Arabian Sea 35.82pct, Bay of Bengal 27.05pct, '
         'Indian Ocean 19.88pct, Andaman Sea 12.82pct, Gulf of Kutch 4.43pct. '
         'Both KPIs added to master_table_v2.csv as new columns.'),
        ('June 11 (Thu)', 'Plotted 10-year historical trajectories (2015-2026) using Seaborn '
         'and Matplotlib. 4-panel chart: species trend, dual-axis plastic+species overlay, '
         'SST trend with linear trendline, sea turtle population indicator. '
         'Species count 122 (2015) to 4,757 (2025) — reporting surge via iNaturalist. '
         'Plastic projected +133pct over project window. SST range 28.17-28.87C.'),
        ('June 12 (Fri)', 'Segmented trend visualizations by Habitat Type: Coral Reefs '
         '(Gulf of Mannar, Lakshadweep, Andaman), Mangroves (Sundarbans, Mumbai coast, '
         'Andhra coast), Open Ocean (all other cells). '
         'Coral Reef: 2,241 species records. Mangrove: 990. Open Ocean: 6,241. '
         '3-panel comparison plot: species trend, plastic bar, heatmap by habitat and year.'),
        ('June 13 (Sat)', 'Exported all 10-year trend visual canvases, heatmaps, and trend line '
         'charts into project /visualizations/ asset folder. '
         'Built dark-theme 5-panel summary dashboard preview for mentor review. '
         'Visualization index generated: 10 PNG assets catalogued with existence check.'),
        ('June 14 (Sun)', 'Committed all Week 4 analytical scripts to version control. '
         'Completed WPR 4. Outlined Week 5 statistical and ML modeling architecture: '
         'Pearson Correlation -> Tipping Point Regression -> K-Means (k=3) -> Silhouette + Folium.'),
    ]
    for date, task in days:
        f.write(f'   {date}:\n   {task}\n\n')

    f.write('3. KEY ANALYTICAL FINDINGS:\n')
    findings = [
        'Arabian Sea: 35.82pct of total plastic density — highest regional share.',
        'PVC and PS (Industrial) dominate hotspot cells — industrial waste is priority intervention.',
        'Species count increase (122 to 4,757) is largely iNaturalist reporting surge, not recovery.',
        'SST range 28.17-28.87C (2015-2023) — peak in 2020 marine heatwave year.',
        'Coral Reef zones carry highest ecological risk: biodiversity density + plastic exposure.',
        'Mangrove zones have lowest plastic density but highest sediment microplastic risk.',
        'master_table_v2.csv: 1,228 rows x 19 cols including KPI columns.',
    ]
    for i, finding in enumerate(findings, 1):
        f.write(f'   [{i}] {finding}\n')

    f.write('\n4. OUTPUTS PRODUCED THIS WEEK:\n')
    for o in ['master_table_v2.csv            — 1,228 rows x 19 cols with KPI columns',
              'hotspots.csv                   — 31 hotspot grid cells (top 20pct density)',
              'trajectory_data.csv            — 2015-2026 year-by-year trend series',
              'species_with_habitat.csv       — species dataset with Habitat_Type labels',
              'visualization_index.txt        — 10 PNG assets catalogued',
              '10 visualization PNGs including dark-theme summary dashboard preview',]:
        f.write(f'   - {o}\n')

    f.write('\n5. ISSUES / BLOCKERS:\n')
    f.write('   Issue #1 (carried): Maldives bbox — climate dataset kept unfiltered.\n')
    f.write('   Observation bias: species count spike (2020+) is iNaturalist reporting surge.\n')
    f.write('   Action: Will control for this in Week 5 correlation analysis.\n\n')

    f.write('6. WEEK 5 ML ARCHITECTURE PLAN (June 15-21):\n')
    for task in ['Pearson Correlation: plastic density x SST x pH x species count.',
                 'p-value significance testing. Linear Regression tipping points.',
                 'Feature scaling with StandardScaler. K-Means initialization (k=3).',
                 'K-Means execution: Critical / At-Risk / Stable zone segmentation.',
                 'Silhouette score evaluation. Folium interactive risk map.',
                 'Document correlation coefficients and cluster centroids.',
                 'Push K-Means weights + statistical notebooks to GitHub. Write WPR 5.']:
        f.write(f'   - {task}\n')

    f.write('\nStudent Signature: Aditya Saxena\n')
    f.write(f'Date: {datetime.datetime.now().strftime("%B %d, %Y")}\n')

print('WPR 4 generated ')
with open(wpr_path) as f: print(f.read())

# %% [markdown]
# ## Step 2 — Pre-Push Asset Verification

# %%
print('PRE-PUSH ASSET VERIFICATION')
print('='*55)
checks = {
    'Processed datasets': glob.glob(DIRS['processed']  + '/*.csv') + glob.glob(DIRS['processed']  + '/*.parquet'),
    'Metadata & JSON':    glob.glob(DIRS['metadata']   + '/*.txt') + glob.glob(DIRS['metadata']   + '/*.json'),
    'Visualizations':     glob.glob(DIRS['visualizations'] + '/*.png') + glob.glob(DIRS['visualizations'] + '/*.html'),
}
total = 0
for cat, files in checks.items():
    seen = set(); unique = [f for f in files if f not in seen and not seen.add(f)]
    print(f'  {cat} ({len(unique)} files):')
    for fp in sorted(unique):
        print(f'     {os.path.basename(fp):<50}  {os.path.getsize(fp)/1024:.1f} KB')
    total += len(unique)
print(f'\nTotal assets ready: {total} → Proceeding to deployment ')

# %% [markdown]
# ---
# ## AUTOMATED GITHUB DEPLOYMENT — STAGES 1–5

# %%
# ==============================================================================
# SPATIO-TEMPORAL OCEAN PLASTIC ANALYSIS - AUTOMATED WORKSPACE INITIALIZATION
# ==============================================================================
import os
import shutil
import getpass

# ------------------------------------------------------------------------------
# STAGE 1: IDENTITY & SECURE CREDENTIAL ENTRY
# ------------------------------------------------------------------------------
print("="*60)
GITHUB_USERNAME = "adityasaxen"
REPO_NAME       = "Ocean_Plastic_Project"
USER_EMAIL      = "adityasaxena2003@gmail.com"

print(f"[TARGET REPO] LINK LOCKED TO: https://github.com/{GITHUB_USERNAME}/{REPO_NAME}")
print("="*60 + "\n")

print("[ACTION REQUIRED] Paste your GitHub Personal Access Token (PAT) below.")
print("-> Note: The text field will look completely blank as you paste for security.")
GITHUB_TOKEN = getpass.getpass("Enter GitHub Token: ").strip()

if not GITHUB_TOKEN:
    raise ValueError("[FATAL ENTRY] Deployment canceled: Valid GitHub token is required.")

# ------------------------------------------------------------------------------
# STAGE 2: FOLDER STRUCTURE GENERATION & DATASET RELOCATION
# ------------------------------------------------------------------------------
print("\n" + "="*60)
print(" STAGE 2: INITIALIZING LOCAL DIRECTORY TREE MATRIX")
print("="*60)

local_root = "/content"
target_dirs = {
    "data":      os.path.join(local_root, "data"),
    "raw":       os.path.join(local_root, "data/raw"),
    "processed": os.path.join(local_root, "data/processed"),
    "metadata":  os.path.join(local_root, "data/metadata"),
    "notebooks": os.path.join(local_root, "notebooks"),
    "viz":       os.path.join(local_root, "visualizations"),
}

for name, path in target_dirs.items():
    if not os.path.exists(path):
        os.makedirs(path)
        print(f"[FOLDER CREATED] Path initialized successfully: {path}")
    else:
        print(f"[FOLDER EXISTS]  Path already present: {path}")

print("\n[INFO] Scanning root folder for uploaded datasets...")
moved_count = 0
for item in os.listdir(local_root):
    if item.endswith('.csv'):
        source_path      = os.path.join(local_root, item)
        destination_path = os.path.join(target_dirs["raw"], item)
        shutil.move(source_path, destination_path)
        print(f" -> Relocated: '{item}' ➔ data/raw/")
        moved_count += 1
print(f"[SUCCESS] Relocation complete. {moved_count} datasets moved into 'data/raw/'.")

for folder in [target_dirs["processed"], target_dirs["metadata"]]:
    gitkeep_path = os.path.join(folder, '.gitkeep')
    with open(gitkeep_path, 'w') as gk:
        gk.write('# Forces Git to preserve this empty folder structure upstream.\n')

# Mirror Drive outputs to /content for staging
print("\n[INFO] Mirroring Drive outputs to /content...")
drive_base = "/content/drive/MyDrive/Ocean_Plastic_Project"
for sub_src, sub_dst in [("data/processed", "processed"), ("data/metadata", "metadata"), ("visualizations", "viz")]:
    src_dir = os.path.join(drive_base, sub_src)
    dst_dir = target_dirs[sub_dst]
    if os.path.exists(src_dir):
        for fname in os.listdir(src_dir):
            try:
                shutil.copy2(os.path.join(src_dir, fname), os.path.join(dst_dir, fname))
                print(f" -> Mirrored: {fname}")
            except Exception as e:
                print(f" -> Skip: {fname} ({e})")

# ------------------------------------------------------------------------------
# STAGE 3: DRIVE MIRRORING (OPTIONAL BACKGROUND ASSISTANCE)
# ------------------------------------------------------------------------------
drive_project_path = "/content/drive/MyDrive/Ocean_Plastic_Project"
if os.path.exists("/content/drive/MyDrive"):
    print("\n[DRIVE DETECTED] Mirroring folder structure to Google Drive...")
    for sub in ["data/raw", "data/processed", "data/metadata", "notebooks", "visualizations"]:
        full_drive_sub = os.path.join(drive_project_path, sub)
        os.makedirs(full_drive_sub, exist_ok=True)
    print("[SUCCESS] Google Drive folders successfully synchronized.")

# ------------------------------------------------------------------------------
# STAGE 4: MODIFIED ASSET PROTECTION RULES (.gitignore Update)
# ------------------------------------------------------------------------------
gitignore_lines = [
    "# Google Colab Local Machine Environments & Cache",
    ".ipynb_checkpoints/",
    "__pycache__/",
    "*.pyc",
    ".virtual_documents/",
    "sample_data/",
    "",
    "# Keep data structure visible on GitHub but ignore hidden operating systems junk",
    ".DS_Store",
    "",
]
with open('/content/.gitignore', 'w') as f:
    f.write("\n".join(gitignore_lines))
print("\n[SUCCESS] Stage 4: Updated .gitignore rules to allow dataset uploads.")

# ------------------------------------------------------------------------------
# STAGE 5: RECURSIVE DEPLOYMENT RUN TO GITHUB
# ------------------------------------------------------------------------------
print("\n" + "="*60)
print(" STAGE 5: TRANSMITTING DATASETS AND COMPLETED STRUCTURE TO GITHUB")
print("="*60)

# 1. Reset background nodes to ensure a clean slate
# !rm -rf /content/.git

# 2. Re-initialize workspace architecture targeting the main branch
# %cd /content
# !git init -b main

# 3. Apply global configuration identifiers
# !git config --global user.name "{GITHUB_USERNAME}"
# !git config --global user.email "{USER_EMAIL}"

# 4. Stage EVERYTHING recursively (including your new data folders and CSVs)
print("[GIT] Staging your full directory trees and datasets...")
# !git add .

# 5. Commit changes to the tracking stack
# !git commit -m "feat: Week 4 complete — hotspot mapping, source attribution, trajectories, habitat segmentation"

# 6. Execute transmission upstream using explicit token authentication
print("\n[GIT] Transmitting folders and files upstream to GitHub server...")
url = f"https://{GITHUB_USERNAME}:{GITHUB_TOKEN}@github.com/{GITHUB_USERNAME}/{REPO_NAME}.git"
# !git push {url} main --force

print("\n" + "="*60)
print("     SUCCESS! DIRECTORY TREE & DATASETS FULLY DEPLOYED TO GITHUB")
print("="*60)
